# %%
import pandas as pd
import numpy as np

# %%
# (1) Используя параметры pandas прочитать красиво пандас 
df = pd.read_csv('UCI_Credit_Card.csv') #TODO

# %%
df
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 0          1    20000.0    2          2         1   24      2      2     -1
# 1          2   120000.0    2          2         2   26     -1      2      0
# 2          3    90000.0    2          2         2   34      0      0      0
# 3          4    50000.0    2          2         1   37      0      0      0
# 4          5    50000.0    1          2         1   57     -1      0     -1
# 5          6    50000.0    1          1         2   37      0      0      0
# 6          7   500000.0    1          1         2   29      0      0      0
# 7          8   100000.0    2          2         2   23      0     -1     -1
# 8          9   140000.0    2          3         1   28      0      0      2
# 9         10    20000.0    1          3         2   35     -2     -2     -2
# 10        11   200000.0    2          3         2   34      0      0      2
# ...

# %%
# (2) выведите, что за типы переменных, сколько пропусков,
df.info()
# для численных значений посчитайте пару статистик (в свободной форме)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
# ID                            30000 non-null int64
# LIMIT_BAL                     30000 non-null float64
# SEX                           30000 non-null int64
# EDUCATION                     30000 non-null int64
# MARRIAGE                      30000 non-null int64
# AGE                           30000 non-null int64
# PAY_0                         30000 non-null int64
# PAY_2                         30000 non-null int64
# PAY_3                         30000 non-null int64
# PAY_4                         30000 non-null int64
# PAY_5                         30000 non-null int64
# PAY_6                         30000 non-null int64
# BILL_AMT1                     30000 non-null float64
# BILL_AMT2                     30000 non-null float64
# BILL_AMT3                     30000 non-null float64
# BILL_AMT4                     30000 non-null float64
# ...

# %%
# (2) выведите, что за типы переменных, сколько пропусков,

df.describe()
# Out:
#                  ID       LIMIT_BAL           SEX     EDUCATION      MARRIAGE  \
# count  30000.000000    30000.000000  30000.000000  30000.000000  30000.000000
# mean   15000.500000   167484.322667      1.603733      1.853133      1.551867
# std     8660.398374   129747.661567      0.489129      0.790349      0.521970
# min        1.000000    10000.000000      1.000000      0.000000      0.000000
# 25%     7500.750000    50000.000000      1.000000      1.000000      1.000000
# 50%    15000.500000   140000.000000      2.000000      2.000000      2.000000
# 75%    22500.250000   240000.000000      2.000000      2.000000      2.000000
# max    30000.000000  1000000.000000      2.000000      6.000000      3.000000
#
#                 AGE         PAY_0         PAY_2         PAY_3         PAY_4  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      35.485500     -0.016700     -0.133767     -0.166200     -0.220667
# ...

# %%
# 2 TODO # для численных значений посчитайте пару статистик (в свободной форме)
df.shape, df.index, df.columns,
# Out:
# ((30000, 25),
#  RangeIndex(start=0, stop=30000, step=1),
#  Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0',
#         'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#         'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#         'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#         'default.payment.next.month'],
#        dtype='object'))

# %%
# (3) посчитать число женщин с университетским образованием
# SEX (1 = male; 2 = female). 
# EDUCATION (1 = graduate school; 2 = university; 3 = high school; 4 = others). 

#TODO df[['SEX', 'EDUCATION']].groupby('EDUCATION').count()
#df[['EDUCATION', 'SEX']].groupby[df['EDUCATION'] == 2 & df['SEX'] == 2].count()
#train[train['Sex'] == 'male'].head()
df[(df['SEX'] == 2) & (df['EDUCATION'] == 2)].count()
# Out:
# ID                            8656
# LIMIT_BAL                     8656
# SEX                           8656
# EDUCATION                     8656
# MARRIAGE                      8656
# AGE                           8656
# PAY_0                         8656
# PAY_2                         8656
# PAY_3                         8656
# PAY_4                         8656
# PAY_5                         8656
# PAY_6                         8656
# BILL_AMT1                     8656
# BILL_AMT2                     8656
# BILL_AMT3                     8656
# BILL_AMT4                     8656
# BILL_AMT5                     8656
# BILL_AMT6                     8656
# PAY_AMT1                      8656
# PAY_AMT2                      8656
# PAY_AMT3                      8656
# PAY_AMT4                      8656
# PAY_AMT5                      8656
# PAY_AMT6                      8656
# default.payment.next.month    8656
# dtype: int64

# %%
# (3) посчитать число женщин с университетским образованием
# SEX (1 = male; 2 = female). 
# EDUCATION (1 = graduate school; 2 = university; 3 = high school; 4 = others). 

#TODO df[['SEX', 'EDUCATION']].groupby('EDUCATION').count()
#df[['EDUCATION', 'SEX']].groupby[df['EDUCATION'] == 2 & df['SEX'] == 2].count()
#train[train['Sex'] == 'male'].head()
#df[(df['SEX'] == 2) & (df['EDUCATION'] == 2)].count()
#df2 = df[['SEX', 'EDUCATION']]
#df2 = pd.DataFrame(df[['SEX', 'EDUCATION']], columns=['SEX', 'EDUCATION'])
#df2.groupby(['SEX', 'EDUCATION']).size()

# %%
# (4) Сгрупировать по "default payment next month" и посчитать медиану для всех показателей начинающихся на BILL_ и PAY_
#TODO 
headers = [x for x in df.columns.values if ('PAY_' in x) | ('BILL_' in x)]
headers
# Out:
# ['PAY_0',
#  'PAY_2',
#  'PAY_3',
#  'PAY_4',
#  'PAY_5',
#  'PAY_6',
#  'BILL_AMT1',
#  'BILL_AMT2',
#  'BILL_AMT3',
#  'BILL_AMT4',
#  'BILL_AMT5',
#  'BILL_AMT6',
#  'PAY_AMT1',
#  'PAY_AMT2',
#  'PAY_AMT3',
#  'PAY_AMT4',
#  'PAY_AMT5',
#  'PAY_AMT6']

# %%
# (4) Сгрупировать по "default payment next month" и посчитать медиану для всех показателей начинающихся на BILL_ и PAY_
#TODO 
df[df['default.payment.next.month']==1][headers].median()
# Out:
# PAY_0            1.0
# PAY_2            0.0
# PAY_3            0.0
# PAY_4            0.0
# PAY_5            0.0
# PAY_6            0.0
# BILL_AMT1    20185.0
# BILL_AMT2    20300.5
# BILL_AMT3    19834.5
# BILL_AMT4    19119.5
# BILL_AMT5    18478.5
# BILL_AMT6    18028.5
# PAY_AMT1      1636.0
# PAY_AMT2      1533.5
# PAY_AMT3      1222.0
# PAY_AMT4      1000.0
# PAY_AMT5      1000.0
# PAY_AMT6      1000.0
# dtype: float64

# %%
# (5) постройте сводную таблицу (pivot table) по SEX, EDUCATION, MARRIAGE
# СТРОИМ ДАТАФРЕЙМ

df1 = df[['ID', 'SEX', 'EDUCATION', 'MARRIAGE']]

# %%
# (5) постройте сводную таблицу (pivot table) по SEX, EDUCATION, MARRIAGE

table = pd.pivot_table(df1, index=['SEX', 'MARRIAGE'], columns='EDUCATION', aggfunc = 'count')

# %%
# (5) постройте сводную таблицу (pivot table) по SEX, EDUCATION, MARRIAGE

table
# Out:
#                ID
# EDUCATION       0       1       2       3     4      5     6
# SEX MARRIAGE
# 1   0         NaN     1.0     1.0    12.0   NaN    NaN   NaN
#     1         2.0  1690.0  2370.0  1048.0  18.0   48.0  14.0
#     2         6.0  2633.0  2940.0   894.0  23.0   46.0  11.0
#     3         NaN    30.0    63.0    36.0   1.0    1.0   NaN
# 2   0         NaN     3.0     5.0    32.0   NaN    NaN   NaN
#     1         2.0  2032.0  4472.0  1813.0  34.0  102.0  14.0
#     2         4.0  4176.0  4080.0  1015.0  45.0   81.0  10.0
#     3         NaN    20.0    99.0    67.0   2.0    2.0   2.0

# %%
# (6) Создать новый строковый столбец в data frame-е, который:
# принимает значение A, если значение LIMIT_BAL <=10000
# принимает значение B, если значение LIMIT_BAL <=100000 и >10000
# принимает значение C, если значение LIMIT_BAL <=200000 и >100000
# принимает значение D, если значение LIMIT_BAL <=400000 и >200000
# принимает значение E, если значение LIMIT_BAL <=700000 и >400000
# принимает значение F, если значение LIMIT_BAL >700000

#TODO

def calculatorNewColumn(limit_bal):
    if limit_bal<10000:
        return "A"
    elif limit_bal<=10000 and limit_bal>10000:
        return "B"
    elif limit_bal<=200000 and limit_bal>100000:
        return 'C'
    elif limit_bal<=400000 and limit_bal>200000:
        return 'D'
    elif limit_bal<=700000 and limit_bal>400000:
        return 'E'
    else:
        return 'F'
    
idx = df.columns.get_loc('LIMIT_BAL')
df['NEW'] =df.apply(lambda row: calculatorNewColumn(row[idx]), axis =1)
df.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1    20000.0    2          2         1   24      2      2     -1     -1
# 1   2   120000.0    2          2         2   26     -1      2      0      0
# 2   3    90000.0    2          2         2   34      0      0      0      0
# 3   4    50000.0    2          2         1   37      0      0      0      0
# 4   5    50000.0    1          2         1   57     -1      0     -1      0
#
#   ...   BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  \
# 0 ...         0.0        0.0       0.0     689.0       0.0       0.0
# 1 ...      3455.0     3261.0       0.0    1000.0    1000.0    1000.0
# 2 ...     14948.0    15549.0    1518.0    1500.0    1000.0    1000.0
# 3 ...     28959.0    29547.0    2000.0    2019.0    1200.0    1100.0
# 4 ...     19146.0    19131.0    2000.0   36681.0   10000.0    9000.0
#
#    PAY_AMT5  PAY_AMT6  default.payment.next.month  NEW
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# (7) построить распределение LIMIT_BAL (гистрограмму)
df['LIMIT_BAL'].hist()

# %%
df #TODO

# %%
# (8) построить зависимость кредитного лимита от образования для каждого пола
# график необходимо сделать очень широким (на весь экран)
_, ax = plt.subplots(figsize=(20,8))
df.pivot_table(values='LIMIT_BAL', index=['EDUCATION', 'SEX']).plot(kind='bar',ax=ax)
plt.show()#TODO

# %%
# (9) построить зависимость кредитного лимита и образования только для одного из полов
_, ax = plt.subplots(figsize=(20,8))
df[df['SEX']==1].pivot_table(values='LIMIT_BAL', index=['EDUCATION']).plot(kind='bar',ax=ax)
plt.show()#TODO

# %%
# (10) построить большой график (подсказка - используя seaborn) для построения завимисости всех возможных пар параметров
# разным цветом выделить разные значение "default payment next month"
# (но так как столбцов много - картинка может получиться "монструозной")
# (поэкспериментируйте над тем как построить подобное сравнение параметров)
# (подсказка - ответ может состоять из несколькольких графиков)
# (если не выйдет - программа минимум - построить один график со всеми параметрами)
import seaborn as sns

#TODO

# %%
df_sub = df.head(50)
df_sub
# Out:
#     ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0    1    20000.0    2          2         1   24      2      2     -1     -1
# 1    2   120000.0    2          2         2   26     -1      2      0      0
# 2    3    90000.0    2          2         2   34      0      0      0      0
# 3    4    50000.0    2          2         1   37      0      0      0      0
# 4    5    50000.0    1          2         1   57     -1      0     -1      0
# 5    6    50000.0    1          1         2   37      0      0      0      0
# 6    7   500000.0    1          1         2   29      0      0      0      0
# 7    8   100000.0    2          2         2   23      0     -1     -1      0
# 8    9   140000.0    2          3         1   28      0      0      2      0
# 9   10    20000.0    1          3         2   35     -2     -2     -2     -2
# 10  11   200000.0    2          3         2   34      0      0      2      0
# ...

# %%
sns.pairplot(df_sub, hue='default.payment.next.month', size=5)
